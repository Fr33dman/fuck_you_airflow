# %%
from pandas import read_csv

from sberpm.ml.graph_structure_prediction._wrapper_prediction_module import WrapperGSPredictor

# %%
df = read_csv('df_time_series.csv')
df.head()
# Out:
#    id  act                                 date
# 0   0    0  2021-01-01 00:00:17.295593117+00:00
# 1   0    1  2021-01-01 00:01:05.762473951+00:00
# 2   0    6  2021-01-01 00:02:08.734856738+00:00
# 3   0    4  2021-01-01 00:02:16.399092203+00:00
# 4   1    0  2020-12-31 23:59:40.705055640+00:00

# %% [markdown]
# #### GSPredictor with default parameters and example data

# %%
gsp = WrapperGSPredictor(
    data=df,
    model_params={
        "notation_params": dict(
            id_col="id",
            status_col="act",
            date_col="date",
            date_end_col=None,
        ),
        "model_params": dict(
            test_size=0.1,
            val_size=0.1,
            pred_period=5,
            period_type='D',
            two_models=False,
            edges=False,
            refit=False,
            quick_mod=True,
        ),
    },
)
# Out:
# Model params: {'test_size': 0.1, 'val_size': 0.1, 'pred_period': 5, 'period_type': 'D', 'two_models': False, 'edges': False, 'refit': False, 'quick_mod': True}
# DataHolder: 'time_format' is not set, recommended to specify it for correct time conversion, e.g., time_format='%d-%m-%Y %H:%M:%S'
# DataHolder: timestamp auto conversion will be done. 'dayfirst' is not set, in ambiguous cases it will be considered as False.
# DataHolder: timestamp auto conversion will be done. 'yearfirst' is not set, in ambiguous cases it will be considered as False.

# %%
# %%time

from sys import warnoptions 
from warnings import simplefilter

if not warnoptions:
    simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore"

    gsp_output = gsp.run_model()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.74947D+03    |proj g|=  8.66428D+05
#   ys=-2.640E-01  -gs= 1.136E+00 BFGS update SKIPPED
#
# At iterate    5    f= -1.61786D-01    |proj g|=  1.19653D+00
#   ys=-1.478E+01  -gs= 1.140E+00 BFGS update SKIPPED
#
# At iterate   10    f= -2.64202D+00    |proj g|=  2.48752D+01
#
# At iterate   15    f= -3.56503D+00    |proj g|=  4.60876D+01
#
# At iterate   20    f= -3.95406D+00    |proj g|=  2.87343D+01
#
# At iterate   25    f= -4.02536D+00    |proj g|=  1.58894D+00
#
# At iterate   30    f= -4.02894D+00    |proj g|=  1.49261D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# ...

# %%
gsp_output
# Out:
#               0_prob    1_prob    6_prob    4_prob    2_prob    5_prob  \
# 2021-03-22  0,257572  0,045955  0,233774  0,027137  0,204093  0,185209
# 2021-03-23  0,256933  0,045121  0,233443  0,026222  0,206467  0,186594
# 2021-03-24  0,257553  0,044459  0,233943  0,025429  0,206825  0,187432
# 2021-03-25  0,257216  0,043633  0,233516  0,024562  0,210009  0,187721
# 2021-03-26  0,257821  0,042978  0,233933   0,02381  0,210298  0,188656
#
#               3_prob 0_duration  1_duration 6_duration 4_duration 2_duration  \
# 2021-03-22   0,04626  67,156301  113,233712  36,823363  92,066645  87,598427
# 2021-03-23  0,045219  67,719874  114,364669  36,752999  91,223799  84,363685
# 2021-03-24  0,044359  67,829423  115,512432  36,686426  90,277413  83,009934
# 2021-03-25  0,043343  67,850717  116,676937  36,623611  82,569746  81,977933
# 2021-03-26  0,042503  67,854857   117,85812  36,564524  84,790093  80,722932
#
#            5_duration 3_duration
# 2021-03-22  33,796518   60,76237
# ...
